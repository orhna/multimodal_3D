# %% [markdown]
# # extended version of the `scannet_openseg.py` script

# %%
import os
import torch
import imageio
import numpy as np
from glob import glob
from tqdm import tqdm
import tensorflow as tf2
import tensorflow.compat.v1 as tf
from tensorflow import io
from os.path import join, exists
from utils.fusion_util import PointCloudToImageMapper, save_fused_feature_no_args, read_bytes
# Out:
# 2023-07-07 18:39:40.826553: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-07 18:39:41.808554: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-07-07 18:39:41.808679: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-07-07 18:39:41.808686: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_384/258404841.py in <module>
#       9 from tensorflow import io
#      10 from os.path import join, exists
# ---> 11 from utils.fusion_util import PointCloudToImageMapper, save_fused_feature_no_args, read_bytes
#
# ModuleNotFoundError: No module named 'utils'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

seed = 1457
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
#!### Dataset specific parameters #####
img_dim = (320, 240) # original images from ScanNet are (640, 480) but in the preprocess they resize  images to (320, 240)
depth_scale = 1000.0
#######################################
visibility_threshold = 0.25 # threshold for the visibility check
cut_num_pixel_boundary = 10  # do not use the features on the image boundary
feat_dim = 768 # CLIP feature dimension

# %%
split = 'exampl'
if split== 'train': # for training set, export a chunk of point cloud
    n_split_points = 2000000
    num_rand_file_per_scene = 1
if split== 'example': # for training set, export a chunk of point cloud
    n_split_points = 2000000
    num_rand_file_per_scene = 1
else: # for the validation set, export the entire point cloud instead of chunks
    n_split_points = 2000000
    num_rand_file_per_scene = 1

#DATA_DIR = "D:/AT3DCV_Data/Preprocessed_OpenScene/data"
#DATA_ROOT = join(DATA_DIR, 'scannet_3d')
#DATA_ROOT_2D = join(DATA_DIR,'scannet_2d')

# for augmented:
DATA_DIR = "/mnt/project/AT3DCV_Data/Preprocessed_OpenScene/data/augmented"
DATA_ROOT = join(DATA_DIR, '3D')
DATA_ROOT_2D = join(DATA_DIR, '2D')


data_paths = sorted(glob(join(DATA_ROOT, split, '*.pth')))
total_num = len(data_paths) # total number of samples in dataset

OUT_DIR = "/mnt/project/AT3DCV_Data/Preprocessed_OpenScene/data/augmented/fused"

#load openseg model
model_path = "/mnt/project/AT3DCV/repo/openseg_model"
openseg_model = tf2.saved_model.load(model_path,tags=[tf.saved_model.tag_constants.SERVING],)
text_emb = tf.zeros([1, 1, feat_dim]) # creating zero tensor for text embeddings

# %%
# load intrinsic parameter
intrinsics=np.loadtxt(os.path.join(DATA_ROOT_2D, 'intrinsics.txt'))

# calculate image pixel-3D points correspondances
point2img_mapper = PointCloudToImageMapper(
        image_dim=img_dim, intrinsics=intrinsics,
        visibility_threshold=visibility_threshold,
        cut_bound=cut_num_pixel_boundary)

process_id_range = ["1,2"]  # to only process samples in this range
id_range = None
if process_id_range is not None:
    id_range = [int(process_id_range[0].split(',')[0]), int(process_id_range[0].split(',')[1])]

# %%
# looping over samples
for i in tqdm(range(total_num)):
    # check the given range for the samples
    if id_range is not None and (i<id_range[0] or i>id_range[1]):
        print('skip ', i, data_paths[i])
        continue
    
    # extraction of the features starts here, not using the provided functions
    # ------------------------------------------------------------------------
    data_path = data_paths[i]
    #scene_id might be different depending on the path string, should be like "scene0000_00"
    scene_id = data_path.split('/')[-1].split('\\')[-1].split('_vh')[0]
    
    # load 3D data (point cloud)
    locs_in = torch.load(data_path)[0]
    n_points = locs_in.shape[0] # number of points
    
    n_interval = num_rand_file_per_scene
    n_finished = 0
    for n in range(n_interval):
        if exists(join(OUT_DIR, scene_id +'_%d.pt'%(n))):
            n_finished += 1
            print(scene_id +'_%d.pt'%(n) + ' already done!')
            continue
    if n_finished == n_interval:
        continue
    
    # short hand for processing 2D features
    scene = join(DATA_ROOT_2D, scene_id)
    img_dirs = sorted(glob(join(scene, 'color/*')), key=lambda x: int(os.path.basename(x)[:-4]))
    num_img = len(img_dirs) # number of images that the scene have
        
    # creating tensors to keep features per 3D point
    n_points_cur = n_points
    counter = torch.zeros((n_points_cur, 1), device = device)
    sum_features = torch.zeros((n_points_cur, feat_dim), device = device)

    vis_id = torch.zeros((n_points_cur, num_img), dtype=int, device=device)
    
    # process images per scene and fuse 2D-3D features
    for img_id, img_dir in enumerate(tqdm(img_dirs)):
        # load pose
        posepath = img_dir.replace('color', 'pose').replace('.jpg', '.txt')
        pose = np.loadtxt(posepath)
        # load depth and convert to meter
        depth = imageio.v2.imread(img_dir.replace('color', 'depth').replace('jpg', 'png')) / depth_scale # (240, 320)
        
        # calculate the 3d-2d mapping based on the depth
        mapping = np.ones([n_points, 4], dtype=int)
        """
        :pose: 4 x 4
        :locs_in: N x 3 format (point cloud)
        :depth: H x W format
        :return: mapping, N x 3 format, (H,W,mask)
        """
        mapping[:, 1:4] = point2img_mapper.compute_mapping(pose, locs_in, depth)
        if mapping[:, 3].sum() == 0: # no points corresponds to this image, skip
            continue     
        mapping = torch.from_numpy(mapping).to(device)
        mask = mapping[:, 3]    # [number of points]
        vis_id[:, img_id] = mask # masking the points corresponding to the image index of the scene, [number of points, num of images per scene]

        # extraction of 2D features with OpenSeg
        # load RGB image
        np_image_string = read_bytes(img_dir) #read_bytes is a simple function to read images as bytes for OpenSeg
        # run OpenSeg
        '''
        results is a dictionary that has = ['region_probs_', 'text_embedding', 'segm_proposal_feats',
                                            'image_embedding_feat', 'pixel_pred_confidence', 'segm_confidence', 
                                            'segm_prediction', 'images', 'region_embeddings', 'region_probs',
                                            'ppixel_ave_feat', 'ppixel_ave_feat_confidence', 'segm_confidence_rw',
                                            'image', 'segm_prediction_rw', 'image_info', 'ppixel_ave_feat_pred',
                                            'pixel_prediction', 'segm_proposal', 'region_logits']
        check OpenSeg repo for more information
        
        '''
        results = openseg_model.signatures['serving_default'](
                        inp_image_bytes = tf.convert_to_tensor(np_image_string),
                        inp_text_emb = text_emb)
        
        img_info = results['image_info']
        
        crop_sz = [
            int(img_info[0, 0] * img_info[2, 0]),
            int(img_info[0, 1] * img_info[2, 1])
        ]
        
        # this parameter is True by default in the original code, regardless of it the shape will be same
        regional_pool = True 
        if regional_pool:
            image_embedding_feat = results['ppixel_ave_feat'][:, :crop_sz[0], :crop_sz[1]] # shape will be : (1, 480, 640, 768)
        else:
            image_embedding_feat = results['image_embedding_feat'][:, :crop_sz[0], :crop_sz[1]] # shape will be : (1, 480, 640, 768)
        
        # resizing with nearest neighbors to 240x320
        img_size=[240, 320] # set to this in the original code
        if img_size is not None:
            feat_2d = tf.cast(tf.image.resize_nearest_neighbor(
                image_embedding_feat, img_size, align_corners=True)[0], dtype=tf.float16).numpy()
        else:
            feat_2d = tf.cast(image_embedding_feat[[0]], dtype=tf.float16).numpy()
        
        # reshaping for the fusion
        feat_2d = torch.from_numpy(feat_2d).permute(2, 0, 1)
        #without this conversion, it gives error while indexing
        mapping = mapping.to(int)
        # fusion
        feat_2d_3d = feat_2d[:, mapping[:, 1], mapping[:, 2]].permute(1, 0).to(device) #has the shape [81369, 768]
        
        # counting the image numbers and corresponding points
        counter[mask!=0]+= 1
        sum_features[mask!=0] += feat_2d_3d[mask!=0] #has the shape [81369, 768]    
        
    counter[counter==0] = 1e-5 # to prevent division by zero
    # dividing sum of the features per point by how many times the points had effect on the feature extraction
    feat_bank = sum_features/counter # [81369, 768]
    point_ids = torch.unique(vis_id.nonzero(as_tuple = False)[:, 0])
    
    #saving the fused features of randomly chosen n_split_points to total of num_rand_file_per_scene files
    save_fused_feature_no_args(feat_bank, point_ids, n_points, OUT_DIR, scene_id, num_rand_file_per_scene, n_split_points)
# Out:
#   0%|                                                                                         | 0/1201 [00:00<?, ?it/s]
# skip  0 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0000_00_vh_clean_2.pth
# scene0000_01_0.pt already done!
#   0%|                                                                                          | 0/309 [00:00<?, ?it/s]
#   0%|▎                                                                                 | 1/309 [00:05<28:13,  5.50s/it]
#   1%|▌                                                                                 | 2/309 [00:11<28:08,  5.50s/it]
#   1%|▊                                                                                 | 3/309 [00:16<27:56,  5.48s/it]
#   1%|█                                                                                 | 4/309 [00:22<28:48,  5.67s/it]
#   2%|█▎                                                                                | 5/309 [00:28<30:12,  5.96s/it]
#   2%|█▌                                                                                | 6/309 [00:35<30:32,  6.05s/it]
#   2%|█▊                                                                                | 7/309 [00:41<30:30,  6.06s/it]
#   3%|██                                                                                | 8/309 [00:47<30:28,  6.07s/it]
#   3%|██▍                                                                               | 9/309 [00:53<30:30,  6.10s/it]
#   3%|██▌                                                                              | 10/309 [00:59<30:31,  6.12s/it]
#   4%|██▉                                                                              | 11/309 [01:05<30:24,  6.12s/it]
#   4%|███▏                                                                             | 12/309 [01:11<30:17,  6.12s/it]
#   4%|███▍                                                                             | 13/309 [01:18<30:31,  6.19s/it]
#   5%|███▋                                                                             | 14/309 [01:24<30:14,  6.15s/it]
#   5%|███▉                                                                             | 15/309 [01:30<30:05,  6.14s/it]
#   5%|████▏                                                                            | 16/309 [01:36<29:54,  6.13s/it]
#   6%|████▍                                                                            | 17/309 [01:42<30:06,  6.19s/it]
#   6%|████▋                                                                            | 18/309 [01:48<29:51,  6.16s/it]
#   6%|████▉                                                                            | 19/309 [01:55<29:56,  6.20s/it]
#   6%|█████▏                                                                           | 20/309 [02:01<30:01,  6.23s/it]
#   7%|█████▌                                                                           | 21/309 [02:07<30:02,  6.26s/it]
#   7%|█████▊                                                                           | 22/309 [02:14<30:08,  6.30s/it]
#   7%|██████                                                                           | 23/309 [02:20<29:55,  6.28s/it]
#   8%|██████▎                                                                          | 24/309 [02:26<30:07,  6.34s/it]
#   8%|██████▌                                                                          | 25/309 [02:33<29:54,  6.32s/it]
#   8%|██████▊                                                                          | 26/309 [02:39<29:47,  6.31s/it]
#   9%|███████                                                                          | 27/309 [02:45<29:35,  6.30s/it]
#   9%|███████▎                                                                         | 28/309 [02:52<29:26,  6.29s/it]
#   9%|███████▌                                                                         | 29/309 [02:58<29:34,  6.34s/it]
#  10%|███████▊                                                                         | 30/309 [03:04<29:16,  6.30s/it]
#  10%|████████▏                                                                        | 31/309 [03:10<28:52,  6.23s/it]
#  10%|████████▍                                                                        | 32/309 [03:16<28:42,  6.22s/it]
#  11%|████████▋                                                                        | 33/309 [03:23<28:43,  6.24s/it]
#  11%|████████▉                                                                        | 34/309 [03:29<28:39,  6.25s/it]
#  11%|█████████▏                                                                       | 35/309 [03:35<28:24,  6.22s/it]
#  12%|█████████▍                                                                       | 36/309 [03:41<28:17,  6.22s/it]
#  12%|█████████▋                                                                       | 37/309 [03:48<28:04,  6.19s/it]
#  12%|█████████▉                                                                       | 38/309 [03:54<27:50,  6.16s/it]
#  13%|██████████▏                                                                      | 39/309 [04:00<28:06,  6.25s/it]
#  13%|██████████▍                                                                      | 40/309 [04:07<29:05,  6.49s/it]
#  13%|██████████▋                                                                      | 41/309 [04:14<30:05,  6.74s/it]
#  14%|███████████                                                                      | 42/309 [04:21<29:54,  6.72s/it]
#  14%|███████████▎                                                                     | 43/309 [04:28<29:38,  6.68s/it]
#  14%|███████████▌                                                                     | 44/309 [04:34<29:30,  6.68s/it]
#  15%|███████████▊                                                                     | 45/309 [04:41<29:19,  6.66s/it]
#  15%|████████████                                                                     | 46/309 [04:48<29:01,  6.62s/it]
#  15%|████████████▎                                                                    | 47/309 [04:54<28:49,  6.60s/it]
#  16%|████████████▌                                                                    | 48/309 [05:01<28:50,  6.63s/it]
#  16%|████████████▊                                                                    | 49/309 [05:08<28:56,  6.68s/it]
#  16%|█████████████                                                                    | 50/309 [05:14<28:36,  6.63s/it]
#  17%|█████████████▎                                                                   | 51/309 [05:21<28:19,  6.59s/it]
#  17%|█████████████▋                                                                   | 52/309 [05:27<28:15,  6.60s/it]
#  17%|█████████████▉                                                                   | 53/309 [05:34<27:59,  6.56s/it]
#  17%|██████████████▏                                                                  | 54/309 [05:40<28:09,  6.63s/it]
#  18%|██████████████▍                                                                  | 55/309 [05:47<28:06,  6.64s/it]
#  18%|██████████████▋                                                                  | 56/309 [05:54<27:58,  6.64s/it]
#  18%|██████████████▉                                                                  | 57/309 [06:00<27:45,  6.61s/it]
#  19%|███████████████▏                                                                 | 58/309 [06:07<27:24,  6.55s/it]
#  19%|███████████████▍                                                                 | 59/309 [06:13<27:06,  6.51s/it]
#  19%|███████████████▋                                                                 | 60/309 [06:20<27:02,  6.51s/it]
#  20%|███████████████▉                                                                 | 61/309 [06:26<27:01,  6.54s/it]
#  20%|████████████████▎                                                                | 62/309 [06:33<26:59,  6.56s/it]
#  20%|████████████████▌                                                                | 63/309 [06:40<27:02,  6.59s/it]
#  21%|████████████████▊                                                                | 64/309 [06:46<26:47,  6.56s/it]
#  21%|█████████████████                                                                | 65/309 [06:52<26:28,  6.51s/it]
#  21%|█████████████████▎                                                               | 66/309 [06:59<26:23,  6.52s/it]
#  22%|█████████████████▌                                                               | 67/309 [07:05<26:13,  6.50s/it]
#  22%|█████████████████▊                                                               | 68/309 [07:12<26:05,  6.50s/it]
#  22%|██████████████████                                                               | 69/309 [07:18<25:51,  6.47s/it]
#  23%|██████████████████▎                                                              | 70/309 [07:25<25:37,  6.43s/it]
#  23%|██████████████████▌                                                              | 71/309 [07:31<25:52,  6.52s/it]
#  23%|██████████████████▊                                                              | 72/309 [07:38<25:53,  6.56s/it]
#  24%|███████████████████▏                                                             | 73/309 [07:45<25:55,  6.59s/it]
#  24%|███████████████████▍                                                             | 74/309 [07:51<25:52,  6.60s/it]
#  24%|███████████████████▋                                                             | 75/309 [07:58<25:29,  6.54s/it]
#  25%|███████████████████▉                                                             | 76/309 [08:04<25:22,  6.54s/it]
#  25%|████████████████████▏                                                            | 77/309 [08:11<25:28,  6.59s/it]
#  25%|████████████████████▍                                                            | 78/309 [08:17<25:06,  6.52s/it]
#  26%|████████████████████▋                                                            | 79/309 [08:24<24:55,  6.50s/it]
#  26%|████████████████████▉                                                            | 80/309 [08:30<24:52,  6.52s/it]
#  26%|█████████████████████▏                                                           | 81/309 [08:37<25:04,  6.60s/it]
#  27%|█████████████████████▍                                                           | 82/309 [08:44<25:02,  6.62s/it]
#  27%|█████████████████████▊                                                           | 83/309 [08:50<25:01,  6.64s/it]
#  27%|██████████████████████                                                           | 84/309 [08:57<25:08,  6.70s/it]
#  28%|██████████████████████▎                                                          | 85/309 [09:04<24:42,  6.62s/it]
#  28%|██████████████████████▌                                                          | 86/309 [09:10<24:38,  6.63s/it]
#  28%|██████████████████████▊                                                          | 87/309 [09:17<24:35,  6.65s/it]
#  28%|███████████████████████                                                          | 88/309 [09:24<24:21,  6.61s/it]
#  29%|███████████████████████▎                                                         | 89/309 [09:30<23:59,  6.54s/it]
#  29%|███████████████████████▌                                                         | 90/309 [09:36<23:43,  6.50s/it]
#  29%|███████████████████████▊                                                         | 91/309 [09:43<23:48,  6.55s/it]
#  30%|████████████████████████                                                         | 92/309 [09:49<23:30,  6.50s/it]
#  30%|████████████████████████▍                                                        | 93/309 [09:56<23:19,  6.48s/it]
#  30%|████████████████████████▋                                                        | 94/309 [10:02<23:00,  6.42s/it]
#  31%|████████████████████████▉                                                        | 95/309 [10:09<22:51,  6.41s/it]
#  31%|█████████████████████████▏                                                       | 96/309 [10:15<22:43,  6.40s/it]
#  31%|█████████████████████████▍                                                       | 97/309 [10:22<23:02,  6.52s/it]
#  32%|█████████████████████████▋                                                       | 98/309 [10:28<22:56,  6.52s/it]
#  32%|█████████████████████████▉                                                       | 99/309 [10:35<22:46,  6.51s/it]
#  32%|█████████████████████████▉                                                      | 100/309 [10:41<22:37,  6.49s/it]
#  33%|██████████████████████████▏                                                     | 101/309 [10:48<22:36,  6.52s/it]
#  33%|██████████████████████████▍                                                     | 102/309 [10:54<22:28,  6.52s/it]
#  33%|██████████████████████████▋                                                     | 103/309 [11:01<22:59,  6.69s/it]
#  34%|██████████████████████████▉                                                     | 104/309 [11:08<22:53,  6.70s/it]
#  34%|███████████████████████████▏                                                    | 105/309 [11:15<22:30,  6.62s/it]
#  34%|███████████████████████████▍                                                    | 106/309 [11:21<22:03,  6.52s/it]
#  35%|███████████████████████████▋                                                    | 107/309 [11:27<21:44,  6.46s/it]
#  35%|███████████████████████████▉                                                    | 108/309 [11:34<21:37,  6.45s/it]
#  35%|████████████████████████████▏                                                   | 109/309 [11:40<21:25,  6.43s/it]
#  36%|████████████████████████████▍                                                   | 110/309 [11:46<21:26,  6.46s/it]
#  36%|████████████████████████████▋                                                   | 111/309 [11:53<21:26,  6.50s/it]
#  36%|████████████████████████████▉                                                   | 112/309 [11:59<21:04,  6.42s/it]
#  37%|█████████████████████████████▎                                                  | 113/309 [12:06<21:12,  6.49s/it]
#  37%|█████████████████████████████▌                                                  | 114/309 [12:12<21:06,  6.49s/it]
#  37%|█████████████████████████████▊                                                  | 115/309 [12:19<21:21,  6.61s/it]
#  38%|██████████████████████████████                                                  | 116/309 [12:26<21:10,  6.58s/it]
#  38%|██████████████████████████████▎                                                 | 117/309 [12:32<21:03,  6.58s/it]
#  38%|██████████████████████████████▌                                                 | 118/309 [12:39<20:37,  6.48s/it]
#  39%|██████████████████████████████▊                                                 | 119/309 [12:45<20:19,  6.42s/it]
#  39%|███████████████████████████████                                                 | 120/309 [12:51<20:08,  6.39s/it]
#  39%|███████████████████████████████▎                                                | 121/309 [12:58<20:03,  6.40s/it]
#  39%|███████████████████████████████▌                                                | 122/309 [13:04<20:00,  6.42s/it]
#  40%|███████████████████████████████▊                                                | 123/309 [13:11<19:58,  6.45s/it]
#  40%|████████████████████████████████                                                | 124/309 [13:17<19:40,  6.38s/it]
#  40%|████████████████████████████████▎                                               | 125/309 [13:23<19:26,  6.34s/it]
#  41%|████████████████████████████████▌                                               | 126/309 [13:29<19:14,  6.31s/it]
#  41%|████████████████████████████████▉                                               | 127/309 [13:36<19:04,  6.29s/it]
#  41%|█████████████████████████████████▏                                              | 128/309 [13:42<18:54,  6.27s/it]
#  42%|█████████████████████████████████▍                                              | 129/309 [13:48<18:43,  6.24s/it]
#  42%|█████████████████████████████████▋                                              | 130/309 [13:54<18:35,  6.23s/it]
#  42%|█████████████████████████████████▉                                              | 131/309 [14:00<18:26,  6.21s/it]
#  43%|██████████████████████████████████▏                                             | 132/309 [14:07<18:17,  6.20s/it]
#  43%|██████████████████████████████████▍                                             | 133/309 [14:13<18:09,  6.19s/it]
#  43%|██████████████████████████████████▋                                             | 134/309 [14:19<18:05,  6.20s/it]
#  44%|██████████████████████████████████▉                                             | 135/309 [14:25<18:00,  6.21s/it]
#  44%|███████████████████████████████████▏                                            | 136/309 [14:32<18:03,  6.26s/it]
#  44%|███████████████████████████████████▍                                            | 137/309 [14:38<18:01,  6.29s/it]
#  45%|███████████████████████████████████▋                                            | 138/309 [14:44<18:09,  6.37s/it]
#  45%|███████████████████████████████████▉                                            | 139/309 [14:51<18:03,  6.37s/it]
#  45%|████████████████████████████████████▏                                           | 140/309 [14:57<18:08,  6.44s/it]
#  46%|████████████████████████████████████▌                                           | 141/309 [15:04<18:02,  6.44s/it]
#  46%|████████████████████████████████████▊                                           | 142/309 [15:11<18:12,  6.54s/it]
#  46%|█████████████████████████████████████                                           | 143/309 [15:17<18:02,  6.52s/it]
#  47%|█████████████████████████████████████▎                                          | 144/309 [15:23<17:36,  6.40s/it]
#  47%|█████████████████████████████████████▌                                          | 145/309 [15:30<17:35,  6.44s/it]
#  47%|█████████████████████████████████████▊                                          | 146/309 [15:36<17:34,  6.47s/it]
#  48%|██████████████████████████████████████                                          | 147/309 [15:43<17:23,  6.44s/it]
#  48%|██████████████████████████████████████▎                                         | 148/309 [15:49<17:11,  6.41s/it]
#  48%|██████████████████████████████████████▌                                         | 149/309 [15:55<16:58,  6.36s/it]
#  49%|██████████████████████████████████████▊                                         | 150/309 [16:02<16:46,  6.33s/it]
#  49%|███████████████████████████████████████                                         | 151/309 [16:08<16:32,  6.28s/it]
#  49%|███████████████████████████████████████▎                                        | 152/309 [16:14<16:18,  6.23s/it]
#  50%|███████████████████████████████████████▌                                        | 153/309 [16:20<16:12,  6.23s/it]
#  50%|███████████████████████████████████████▊                                        | 154/309 [16:26<16:02,  6.21s/it]
#  50%|████████████████████████████████████████▏                                       | 155/309 [16:33<16:03,  6.26s/it]
#  50%|████████████████████████████████████████▍                                       | 156/309 [16:39<15:51,  6.22s/it]
#  51%|████████████████████████████████████████▋                                       | 157/309 [16:45<15:46,  6.23s/it]
#  51%|████████████████████████████████████████▉                                       | 158/309 [16:51<15:40,  6.23s/it]
#  51%|█████████████████████████████████████████▏                                      | 159/309 [16:58<15:41,  6.28s/it]
#  52%|█████████████████████████████████████████▍                                      | 160/309 [17:04<15:43,  6.33s/it]
#  52%|█████████████████████████████████████████▋                                      | 161/309 [17:10<15:37,  6.33s/it]
#  52%|█████████████████████████████████████████▉                                      | 162/309 [17:17<15:34,  6.36s/it]
#  53%|██████████████████████████████████████████▏                                     | 163/309 [17:23<15:28,  6.36s/it]
#  53%|██████████████████████████████████████████▍                                     | 164/309 [17:29<15:18,  6.34s/it]
#  53%|██████████████████████████████████████████▋                                     | 165/309 [17:36<15:10,  6.32s/it]
#  54%|██████████████████████████████████████████▉                                     | 166/309 [17:42<14:59,  6.29s/it]
#  54%|███████████████████████████████████████████▏                                    | 167/309 [17:48<14:55,  6.30s/it]
#  54%|███████████████████████████████████████████▍                                    | 168/309 [17:55<14:51,  6.33s/it]
#  55%|███████████████████████████████████████████▊                                    | 169/309 [18:01<14:43,  6.31s/it]
#  55%|████████████████████████████████████████████                                    | 170/309 [18:07<14:38,  6.32s/it]
#  55%|████████████████████████████████████████████▎                                   | 171/309 [18:14<14:32,  6.32s/it]
#  56%|████████████████████████████████████████████▌                                   | 172/309 [18:20<14:26,  6.33s/it]
#  56%|████████████████████████████████████████████▊                                   | 173/309 [18:27<14:32,  6.41s/it]
#  56%|█████████████████████████████████████████████                                   | 174/309 [18:33<14:31,  6.46s/it]
#  57%|█████████████████████████████████████████████▎                                  | 175/309 [18:39<14:20,  6.42s/it]
#  57%|█████████████████████████████████████████████▌                                  | 176/309 [18:46<14:14,  6.43s/it]
#  57%|█████████████████████████████████████████████▊                                  | 177/309 [18:52<14:05,  6.40s/it]
#  58%|██████████████████████████████████████████████                                  | 178/309 [18:59<13:59,  6.41s/it]
#  58%|██████████████████████████████████████████████▎                                 | 179/309 [19:05<13:47,  6.36s/it]
#  58%|██████████████████████████████████████████████▌                                 | 180/309 [19:11<13:34,  6.31s/it]
#  59%|██████████████████████████████████████████████▊                                 | 181/309 [19:17<13:25,  6.29s/it]
#  59%|███████████████████████████████████████████████                                 | 182/309 [19:24<13:16,  6.27s/it]
#  59%|███████████████████████████████████████████████▍                                | 183/309 [19:30<13:09,  6.26s/it]
#  60%|███████████████████████████████████████████████▋                                | 184/309 [19:36<13:11,  6.33s/it]
#  60%|███████████████████████████████████████████████▉                                | 185/309 [19:43<13:09,  6.37s/it]
#  60%|████████████████████████████████████████████████▏                               | 186/309 [19:49<13:09,  6.42s/it]
#  61%|████████████████████████████████████████████████▍                               | 187/309 [19:56<13:03,  6.42s/it]
#  61%|████████████████████████████████████████████████▋                               | 188/309 [20:02<12:52,  6.38s/it]
#  61%|████████████████████████████████████████████████▉                               | 189/309 [20:08<12:42,  6.36s/it]
#  61%|█████████████████████████████████████████████████▏                              | 190/309 [20:15<12:43,  6.41s/it]
#  62%|█████████████████████████████████████████████████▍                              | 191/309 [20:21<12:32,  6.38s/it]
#  62%|█████████████████████████████████████████████████▋                              | 192/309 [20:27<12:23,  6.35s/it]
#  62%|█████████████████████████████████████████████████▉                              | 193/309 [20:34<12:29,  6.46s/it]
#  63%|██████████████████████████████████████████████████▏                             | 194/309 [20:41<12:22,  6.46s/it]
#  63%|██████████████████████████████████████████████████▍                             | 195/309 [20:47<12:16,  6.46s/it]
#  63%|██████████████████████████████████████████████████▋                             | 196/309 [20:54<12:07,  6.44s/it]
#  64%|███████████████████████████████████████████████████                             | 197/309 [21:00<11:59,  6.42s/it]
#  64%|███████████████████████████████████████████████████▎                            | 198/309 [21:06<11:55,  6.44s/it]
#  64%|███████████████████████████████████████████████████▌                            | 199/309 [21:13<11:46,  6.42s/it]
#  65%|███████████████████████████████████████████████████▊                            | 200/309 [21:19<11:38,  6.41s/it]
#  65%|████████████████████████████████████████████████████                            | 201/309 [21:26<11:30,  6.40s/it]
#  65%|████████████████████████████████████████████████████▎                           | 202/309 [21:32<11:32,  6.48s/it]
#  66%|████████████████████████████████████████████████████▌                           | 203/309 [21:39<11:31,  6.52s/it]
#  66%|████████████████████████████████████████████████████▊                           | 204/309 [21:46<11:38,  6.65s/it]
#  66%|█████████████████████████████████████████████████████                           | 205/309 [21:53<11:38,  6.72s/it]
#  67%|█████████████████████████████████████████████████████▎                          | 206/309 [21:59<11:21,  6.61s/it]
#  67%|█████████████████████████████████████████████████████▌                          | 207/309 [22:05<11:07,  6.54s/it]
#  67%|█████████████████████████████████████████████████████▊                          | 208/309 [22:12<10:57,  6.51s/it]
#  68%|██████████████████████████████████████████████████████                          | 209/309 [22:18<10:46,  6.47s/it]
#  68%|██████████████████████████████████████████████████████▎                         | 210/309 [22:25<10:37,  6.44s/it]
#  68%|██████████████████████████████████████████████████████▋                         | 211/309 [22:31<10:28,  6.41s/it]
#  69%|██████████████████████████████████████████████████████▉                         | 212/309 [22:37<10:20,  6.40s/it]
#  69%|███████████████████████████████████████████████████████▏                        | 213/309 [22:44<10:17,  6.43s/it]
#  69%|███████████████████████████████████████████████████████▍                        | 214/309 [22:50<10:12,  6.44s/it]
#  70%|███████████████████████████████████████████████████████▋                        | 215/309 [22:57<10:06,  6.45s/it]
#  70%|███████████████████████████████████████████████████████▉                        | 216/309 [23:03<10:03,  6.49s/it]
#  70%|████████████████████████████████████████████████████████▏                       | 217/309 [23:10<09:57,  6.49s/it]
#  71%|████████████████████████████████████████████████████████▍                       | 218/309 [23:16<09:50,  6.48s/it]
#  71%|████████████████████████████████████████████████████████▋                       | 219/309 [23:23<09:38,  6.42s/it]
#  71%|████████████████████████████████████████████████████████▉                       | 220/309 [23:29<09:33,  6.45s/it]
#  72%|█████████████████████████████████████████████████████████▏                      | 221/309 [23:35<09:27,  6.45s/it]
#  72%|█████████████████████████████████████████████████████████▍                      | 222/309 [23:42<09:19,  6.43s/it]
#  72%|█████████████████████████████████████████████████████████▋                      | 223/309 [23:49<09:20,  6.52s/it]
#  72%|█████████████████████████████████████████████████████████▉                      | 224/309 [23:55<09:10,  6.48s/it]
#  73%|██████████████████████████████████████████████████████████▎                     | 225/309 [24:01<09:01,  6.44s/it]
#  73%|██████████████████████████████████████████████████████████▌                     | 226/309 [24:08<08:53,  6.42s/it]
#  73%|██████████████████████████████████████████████████████████▊                     | 227/309 [24:14<08:45,  6.41s/it]
#  74%|███████████████████████████████████████████████████████████                     | 228/309 [24:20<08:38,  6.40s/it]
#  74%|███████████████████████████████████████████████████████████▎                    | 229/309 [24:27<08:38,  6.48s/it]
#  74%|███████████████████████████████████████████████████████████▌                    | 230/309 [24:33<08:29,  6.44s/it]
#  75%|███████████████████████████████████████████████████████████▊                    | 231/309 [24:40<08:30,  6.54s/it]
#  75%|████████████████████████████████████████████████████████████                    | 232/309 [24:47<08:24,  6.55s/it]
#  75%|████████████████████████████████████████████████████████████▎                   | 233/309 [24:53<08:16,  6.54s/it]
#  76%|████████████████████████████████████████████████████████████▌                   | 234/309 [25:00<08:08,  6.51s/it]
#  76%|████████████████████████████████████████████████████████████▊                   | 235/309 [25:06<07:57,  6.45s/it]
#  76%|█████████████████████████████████████████████████████████████                   | 236/309 [25:13<07:50,  6.44s/it]
#  77%|█████████████████████████████████████████████████████████████▎                  | 237/309 [25:19<07:44,  6.45s/it]
#  77%|█████████████████████████████████████████████████████████████▌                  | 238/309 [25:25<07:38,  6.46s/it]
#  77%|█████████████████████████████████████████████████████████████▉                  | 239/309 [25:32<07:30,  6.44s/it]
#  78%|██████████████████████████████████████████████████████████████▏                 | 240/309 [25:38<07:24,  6.44s/it]
#  78%|██████████████████████████████████████████████████████████████▍                 | 241/309 [25:44<07:12,  6.37s/it]
#  78%|██████████████████████████████████████████████████████████████▋                 | 242/309 [25:51<07:08,  6.39s/it]
#  79%|██████████████████████████████████████████████████████████████▉                 | 243/309 [25:57<06:59,  6.35s/it]
#  79%|███████████████████████████████████████████████████████████████▏                | 244/309 [26:03<06:49,  6.30s/it]
#  79%|███████████████████████████████████████████████████████████████▍                | 245/309 [26:10<06:43,  6.30s/it]
#  80%|███████████████████████████████████████████████████████████████▋                | 246/309 [26:16<06:42,  6.38s/it]
#  80%|███████████████████████████████████████████████████████████████▉                | 247/309 [26:23<06:33,  6.35s/it]
#  80%|████████████████████████████████████████████████████████████████▏               | 248/309 [26:29<06:30,  6.41s/it]
#  81%|████████████████████████████████████████████████████████████████▍               | 249/309 [26:35<06:21,  6.36s/it]
#  81%|████████████████████████████████████████████████████████████████▋               | 250/309 [26:42<06:16,  6.39s/it]
#  81%|████████████████████████████████████████████████████████████████▉               | 251/309 [26:48<06:07,  6.33s/it]
#  82%|█████████████████████████████████████████████████████████████████▏              | 252/309 [26:54<05:59,  6.31s/it]
#  82%|█████████████████████████████████████████████████████████████████▌              | 253/309 [27:00<05:52,  6.29s/it]
#  82%|█████████████████████████████████████████████████████████████████▊              | 254/309 [27:07<05:48,  6.34s/it]
#  83%|██████████████████████████████████████████████████████████████████              | 255/309 [27:13<05:45,  6.40s/it]
#  83%|██████████████████████████████████████████████████████████████████▎             | 256/309 [27:20<05:44,  6.51s/it]
#  83%|██████████████████████████████████████████████████████████████████▌             | 257/309 [27:27<05:40,  6.54s/it]
#  83%|██████████████████████████████████████████████████████████████████▊             | 258/309 [27:33<05:32,  6.51s/it]
#  84%|███████████████████████████████████████████████████████████████████             | 259/309 [27:40<05:24,  6.50s/it]
#  84%|███████████████████████████████████████████████████████████████████▎            | 260/309 [27:46<05:16,  6.46s/it]
#  84%|███████████████████████████████████████████████████████████████████▌            | 261/309 [27:53<05:11,  6.48s/it]
#  85%|███████████████████████████████████████████████████████████████████▊            | 262/309 [27:59<05:05,  6.49s/it]
#  85%|████████████████████████████████████████████████████████████████████            | 263/309 [28:05<04:55,  6.42s/it]
#  85%|████████████████████████████████████████████████████████████████████▎           | 264/309 [28:12<04:47,  6.39s/it]
#  86%|████████████████████████████████████████████████████████████████████▌           | 265/309 [28:18<04:41,  6.40s/it]
#  86%|████████████████████████████████████████████████████████████████████▊           | 266/309 [28:25<04:35,  6.42s/it]
#  86%|█████████████████████████████████████████████████████████████████████▏          | 267/309 [28:31<04:28,  6.40s/it]
#  87%|█████████████████████████████████████████████████████████████████████▍          | 268/309 [28:37<04:20,  6.35s/it]
#  87%|█████████████████████████████████████████████████████████████████████▋          | 269/309 [28:44<04:15,  6.39s/it]
#  87%|█████████████████████████████████████████████████████████████████████▉          | 270/309 [28:50<04:09,  6.40s/it]
#  88%|██████████████████████████████████████████████████████████████████████▏         | 271/309 [28:57<04:03,  6.42s/it]
#  88%|██████████████████████████████████████████████████████████████████████▍         | 272/309 [29:03<03:57,  6.42s/it]
#  88%|██████████████████████████████████████████████████████████████████████▋         | 273/309 [29:09<03:49,  6.38s/it]
#  89%|██████████████████████████████████████████████████████████████████████▉         | 274/309 [29:16<03:45,  6.44s/it]
#  89%|███████████████████████████████████████████████████████████████████████▏        | 275/309 [29:22<03:37,  6.39s/it]
#  89%|███████████████████████████████████████████████████████████████████████▍        | 276/309 [29:28<03:29,  6.34s/it]
#  90%|███████████████████████████████████████████████████████████████████████▋        | 277/309 [29:35<03:23,  6.37s/it]
#  90%|███████████████████████████████████████████████████████████████████████▉        | 278/309 [29:41<03:17,  6.38s/it]
#  90%|████████████████████████████████████████████████████████████████████████▏       | 279/309 [29:48<03:10,  6.35s/it]
#  91%|████████████████████████████████████████████████████████████████████████▍       | 280/309 [29:54<03:03,  6.32s/it]
#  91%|████████████████████████████████████████████████████████████████████████▊       | 281/309 [30:00<02:57,  6.33s/it]
#  91%|█████████████████████████████████████████████████████████████████████████       | 282/309 [30:06<02:50,  6.31s/it]
#  92%|█████████████████████████████████████████████████████████████████████████▎      | 283/309 [30:13<02:43,  6.30s/it]
#  92%|█████████████████████████████████████████████████████████████████████████▌      | 284/309 [30:19<02:37,  6.30s/it]
#  92%|█████████████████████████████████████████████████████████████████████████▊      | 285/309 [30:25<02:30,  6.26s/it]
#  93%|██████████████████████████████████████████████████████████████████████████      | 286/309 [30:31<02:23,  6.26s/it]
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 287/309 [30:38<02:16,  6.23s/it]
#  93%|██████████████████████████████████████████████████████████████████████████▌     | 288/309 [30:44<02:10,  6.22s/it]
#  94%|██████████████████████████████████████████████████████████████████████████▊     | 289/309 [30:50<02:03,  6.20s/it]
#  94%|███████████████████████████████████████████████████████████████████████████     | 290/309 [30:56<01:57,  6.20s/it]
#  94%|███████████████████████████████████████████████████████████████████████████▎    | 291/309 [31:02<01:51,  6.22s/it]
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 292/309 [31:08<01:45,  6.20s/it]
#  95%|███████████████████████████████████████████████████████████████████████████▊    | 293/309 [31:15<01:38,  6.19s/it]
#  95%|████████████████████████████████████████████████████████████████████████████    | 294/309 [31:21<01:32,  6.19s/it]
#  95%|████████████████████████████████████████████████████████████████████████████▍   | 295/309 [31:27<01:26,  6.19s/it]
#  96%|████████████████████████████████████████████████████████████████████████████▋   | 296/309 [31:33<01:20,  6.21s/it]
#  96%|████████████████████████████████████████████████████████████████████████████▉   | 297/309 [31:39<01:14,  6.20s/it]
#  96%|█████████████████████████████████████████████████████████████████████████████▏  | 298/309 [31:46<01:07,  6.18s/it]
#  97%|█████████████████████████████████████████████████████████████████████████████▍  | 299/309 [31:52<01:02,  6.24s/it]
#  97%|█████████████████████████████████████████████████████████████████████████████▋  | 300/309 [31:58<00:55,  6.21s/it]
#  97%|█████████████████████████████████████████████████████████████████████████████▉  | 301/309 [32:04<00:49,  6.20s/it]
#  98%|██████████████████████████████████████████████████████████████████████████████▏ | 302/309 [32:11<00:43,  6.21s/it]
#  98%|██████████████████████████████████████████████████████████████████████████████▍ | 303/309 [32:17<00:37,  6.21s/it]
#  98%|██████████████████████████████████████████████████████████████████████████████▋ | 304/309 [32:23<00:30,  6.19s/it]
#  99%|██████████████████████████████████████████████████████████████████████████████▉ | 305/309 [32:29<00:24,  6.19s/it]
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 306/309 [32:35<00:18,  6.20s/it]
#  99%|███████████████████████████████████████████████████████████████████████████████▍| 307/309 [32:42<00:12,  6.20s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████▋| 308/309 [32:48<00:06,  6.20s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 309/309 [32:54<00:00,  6.39s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1201/1201 [32:55<00:00,  1.64s/it]
# D:/AT3DCV_Data/Preprocessed_OpenScene/data/scannet_fused_features/test_whole\scene0000_02_0.pt is saved!
# skip  3 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0001_00_vh_clean_2.pth
# skip  4 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0001_01_vh_clean_2.pth
# skip  5 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0002_00_vh_clean_2.pth
# skip  6 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0002_01_vh_clean_2.pth
# skip  7 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0003_00_vh_clean_2.pth
# skip  8 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0003_01_vh_clean_2.pth
# skip  9 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0003_02_vh_clean_2.pth
# skip  10 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0004_00_vh_clean_2.pth
# skip  11 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0005_00_vh_clean_2.pth
# skip  12 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0005_01_vh_clean_2.pth
# skip  13 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0006_00_vh_clean_2.pth
# skip  14 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0006_01_vh_clean_2.pth
# skip  15 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0006_02_vh_clean_2.pth
# skip  16 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0007_00_vh_clean_2.pth
# skip  17 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0008_00_vh_clean_2.pth
# skip  18 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0009_00_vh_clean_2.pth
# skip  19 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0009_01_vh_clean_2.pth
# skip  20 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0009_02_vh_clean_2.pth
# skip  21 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0010_00_vh_clean_2.pth
# skip  22 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0010_01_vh_clean_2.pth
# skip  23 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0012_00_vh_clean_2.pth
# skip  24 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0012_01_vh_clean_2.pth
# skip  25 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0012_02_vh_clean_2.pth
# skip  26 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0013_00_vh_clean_2.pth
# skip  27 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0013_01_vh_clean_2.pth
# skip  28 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0013_02_vh_clean_2.pth
# skip  29 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0014_00_vh_clean_2.pth
# skip  30 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0016_00_vh_clean_2.pth
# skip  31 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0016_01_vh_clean_2.pth
# skip  32 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0016_02_vh_clean_2.pth
# skip  33 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0017_00_vh_clean_2.pth
# skip  34 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0017_01_vh_clean_2.pth
# skip  35 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0017_02_vh_clean_2.pth
# skip  36 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0018_00_vh_clean_2.pth
# skip  37 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0020_00_vh_clean_2.pth
# skip  38 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0020_01_vh_clean_2.pth
# skip  39 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0021_00_vh_clean_2.pth
# skip  40 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0022_00_vh_clean_2.pth
# skip  41 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0022_01_vh_clean_2.pth
# skip  42 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0023_00_vh_clean_2.pth
# skip  43 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0024_00_vh_clean_2.pth
# skip  44 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0024_01_vh_clean_2.pth
# skip  45 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0024_02_vh_clean_2.pth
# skip  46 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0026_00_vh_clean_2.pth
# skip  47 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0027_00_vh_clean_2.pth
# skip  48 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0027_01_vh_clean_2.pth
# skip  49 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0027_02_vh_clean_2.pth
# skip  50 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0028_00_vh_clean_2.pth
# skip  51 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0029_00_vh_clean_2.pth
# skip  52 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0029_01_vh_clean_2.pth
# skip  53 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0029_02_vh_clean_2.pth
# skip  54 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0031_00_vh_clean_2.pth
# skip  55 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0031_01_vh_clean_2.pth
# skip  56 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0031_02_vh_clean_2.pth
# skip  57 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0032_00_vh_clean_2.pth
# skip  58 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0032_01_vh_clean_2.pth
# skip  59 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0033_00_vh_clean_2.pth
# skip  60 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0034_00_vh_clean_2.pth
# skip  61 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0034_01_vh_clean_2.pth
# skip  62 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0034_02_vh_clean_2.pth
# skip  63 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0035_00_vh_clean_2.pth
# skip  64 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0035_01_vh_clean_2.pth
# skip  65 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0036_00_vh_clean_2.pth
# skip  66 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0036_01_vh_clean_2.pth
# skip  67 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0037_00_vh_clean_2.pth
# skip  68 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0038_00_vh_clean_2.pth
# skip  69 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0038_01_vh_clean_2.pth
# skip  70 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0038_02_vh_clean_2.pth
# skip  71 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0039_00_vh_clean_2.pth
# skip  72 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0039_01_vh_clean_2.pth
# skip  73 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0040_00_vh_clean_2.pth
# skip  74 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0040_01_vh_clean_2.pth
# skip  75 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0041_00_vh_clean_2.pth
# skip  76 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0041_01_vh_clean_2.pth
# skip  77 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0042_00_vh_clean_2.pth
# skip  78 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0042_01_vh_clean_2.pth
# skip  79 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0042_02_vh_clean_2.pth
# skip  80 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0043_00_vh_clean_2.pth
# skip  81 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0043_01_vh_clean_2.pth
# skip  82 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0044_00_vh_clean_2.pth
# skip  83 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0044_01_vh_clean_2.pth
# skip  84 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0044_02_vh_clean_2.pth
# skip  85 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0045_00_vh_clean_2.pth
# skip  86 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0045_01_vh_clean_2.pth
# skip  87 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0047_00_vh_clean_2.pth
# skip  88 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0048_00_vh_clean_2.pth
# skip  89 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0048_01_vh_clean_2.pth
# skip  90 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0049_00_vh_clean_2.pth
# skip  91 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0051_00_vh_clean_2.pth
# skip  92 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0051_01_vh_clean_2.pth
# skip  93 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0051_02_vh_clean_2.pth
# skip  94 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0051_03_vh_clean_2.pth
# skip  95 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0052_00_vh_clean_2.pth
# skip  96 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0052_01_vh_clean_2.pth
# skip  97 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0052_02_vh_clean_2.pth
# skip  98 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0053_00_vh_clean_2.pth
# skip  99 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0054_00_vh_clean_2.pth
# skip  100 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0055_00_vh_clean_2.pth
# skip  101 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0055_01_vh_clean_2.pth
# skip  102 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0055_02_vh_clean_2.pth
# skip  103 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0056_00_vh_clean_2.pth
# skip  104 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0056_01_vh_clean_2.pth
# skip  105 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0057_00_vh_clean_2.pth
# skip  106 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0057_01_vh_clean_2.pth
# skip  107 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0058_00_vh_clean_2.pth
# skip  108 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0058_01_vh_clean_2.pth
# ...
# skip  1040 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0588_01_vh_clean_2.pth
# skip  1041 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0588_02_vh_clean_2.pth
# skip  1042 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0588_03_vh_clean_2.pth
# skip  1043 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0589_00_vh_clean_2.pth
# skip  1044 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0589_01_vh_clean_2.pth
# skip  1045 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0589_02_vh_clean_2.pth
# skip  1046 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0590_00_vh_clean_2.pth
# skip  1047 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0590_01_vh_clean_2.pth
# skip  1048 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0592_00_vh_clean_2.pth
# skip  1049 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0592_01_vh_clean_2.pth
# skip  1050 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0594_00_vh_clean_2.pth
# skip  1051 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0596_00_vh_clean_2.pth
# skip  1052 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0596_01_vh_clean_2.pth
# skip  1053 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0596_02_vh_clean_2.pth
# skip  1054 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0597_00_vh_clean_2.pth
# skip  1055 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0597_01_vh_clean_2.pth
# skip  1056 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0597_02_vh_clean_2.pth
# skip  1057 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0600_00_vh_clean_2.pth
# skip  1058 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0600_01_vh_clean_2.pth
# skip  1059 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0600_02_vh_clean_2.pth
# skip  1060 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0601_00_vh_clean_2.pth
# skip  1061 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0601_01_vh_clean_2.pth
# skip  1062 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0602_00_vh_clean_2.pth
# skip  1063 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0603_00_vh_clean_2.pth
# skip  1064 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0603_01_vh_clean_2.pth
# skip  1065 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0604_00_vh_clean_2.pth
# skip  1066 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0604_01_vh_clean_2.pth
# skip  1067 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0604_02_vh_clean_2.pth
# skip  1068 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0605_00_vh_clean_2.pth
# skip  1069 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0605_01_vh_clean_2.pth
# skip  1070 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0610_00_vh_clean_2.pth
# skip  1071 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0610_01_vh_clean_2.pth
# skip  1072 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0610_02_vh_clean_2.pth
# skip  1073 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0611_00_vh_clean_2.pth
# skip  1074 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0611_01_vh_clean_2.pth
# skip  1075 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0612_00_vh_clean_2.pth
# skip  1076 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0612_01_vh_clean_2.pth
# skip  1077 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0613_00_vh_clean_2.pth
# skip  1078 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0613_01_vh_clean_2.pth
# skip  1079 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0613_02_vh_clean_2.pth
# skip  1080 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0614_00_vh_clean_2.pth
# skip  1081 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0614_01_vh_clean_2.pth
# skip  1082 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0614_02_vh_clean_2.pth
# skip  1083 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0615_00_vh_clean_2.pth
# skip  1084 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0615_01_vh_clean_2.pth
# skip  1085 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0617_00_vh_clean_2.pth
# skip  1086 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0619_00_vh_clean_2.pth
# skip  1087 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0620_00_vh_clean_2.pth
# skip  1088 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0620_01_vh_clean_2.pth
# skip  1089 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0622_00_vh_clean_2.pth
# skip  1090 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0622_01_vh_clean_2.pth
# skip  1091 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0623_00_vh_clean_2.pth
# skip  1092 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0623_01_vh_clean_2.pth
# skip  1093 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0624_00_vh_clean_2.pth
# skip  1094 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0625_00_vh_clean_2.pth
# skip  1095 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0625_01_vh_clean_2.pth
# skip  1096 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0626_00_vh_clean_2.pth
# skip  1097 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0626_01_vh_clean_2.pth
# skip  1098 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0626_02_vh_clean_2.pth
# skip  1099 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0627_00_vh_clean_2.pth
# skip  1100 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0627_01_vh_clean_2.pth
# skip  1101 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0628_00_vh_clean_2.pth
# skip  1102 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0628_01_vh_clean_2.pth
# skip  1103 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0628_02_vh_clean_2.pth
# skip  1104 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_00_vh_clean_2.pth
# skip  1105 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_01_vh_clean_2.pth
# skip  1106 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_02_vh_clean_2.pth
# skip  1107 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_03_vh_clean_2.pth
# skip  1108 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_04_vh_clean_2.pth
# skip  1109 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_05_vh_clean_2.pth
# skip  1110 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0630_06_vh_clean_2.pth
# skip  1111 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0631_00_vh_clean_2.pth
# skip  1112 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0631_01_vh_clean_2.pth
# skip  1113 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0631_02_vh_clean_2.pth
# skip  1114 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0632_00_vh_clean_2.pth
# skip  1115 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0634_00_vh_clean_2.pth
# skip  1116 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0635_00_vh_clean_2.pth
# skip  1117 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0635_01_vh_clean_2.pth
# skip  1118 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0636_00_vh_clean_2.pth
# skip  1119 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0637_00_vh_clean_2.pth
# skip  1120 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0638_00_vh_clean_2.pth
# skip  1121 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0639_00_vh_clean_2.pth
# skip  1122 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0640_00_vh_clean_2.pth
# skip  1123 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0640_01_vh_clean_2.pth
# skip  1124 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0640_02_vh_clean_2.pth
# skip  1125 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0641_00_vh_clean_2.pth
# skip  1126 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0642_00_vh_clean_2.pth
# skip  1127 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0642_01_vh_clean_2.pth
# skip  1128 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0642_02_vh_clean_2.pth
# skip  1129 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0642_03_vh_clean_2.pth
# skip  1130 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0646_00_vh_clean_2.pth
# skip  1131 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0646_01_vh_clean_2.pth
# skip  1132 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0646_02_vh_clean_2.pth
# skip  1133 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0649_00_vh_clean_2.pth
# skip  1134 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0649_01_vh_clean_2.pth
# skip  1135 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0650_00_vh_clean_2.pth
# skip  1136 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0654_00_vh_clean_2.pth
# skip  1137 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0654_01_vh_clean_2.pth
# skip  1138 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0656_00_vh_clean_2.pth
# skip  1139 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0656_01_vh_clean_2.pth
# skip  1140 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0656_02_vh_clean_2.pth
# skip  1141 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0656_03_vh_clean_2.pth
# skip  1142 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0657_00_vh_clean_2.pth
# skip  1143 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0659_00_vh_clean_2.pth
# skip  1144 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0659_01_vh_clean_2.pth
# skip  1145 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0661_00_vh_clean_2.pth
# skip  1146 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0662_00_vh_clean_2.pth
# skip  1147 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0662_01_vh_clean_2.pth
# skip  1148 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0662_02_vh_clean_2.pth
# skip  1149 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0666_00_vh_clean_2.pth
# skip  1150 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0666_01_vh_clean_2.pth
# skip  1151 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0666_02_vh_clean_2.pth
# skip  1152 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0667_00_vh_clean_2.pth
# skip  1153 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0667_01_vh_clean_2.pth
# skip  1154 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0667_02_vh_clean_2.pth
# skip  1155 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0668_00_vh_clean_2.pth
# skip  1156 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0669_00_vh_clean_2.pth
# skip  1157 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0669_01_vh_clean_2.pth
# skip  1158 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0672_00_vh_clean_2.pth
# skip  1159 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0672_01_vh_clean_2.pth
# skip  1160 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_00_vh_clean_2.pth
# skip  1161 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_01_vh_clean_2.pth
# skip  1162 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_02_vh_clean_2.pth
# skip  1163 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_03_vh_clean_2.pth
# skip  1164 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_04_vh_clean_2.pth
# skip  1165 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0673_05_vh_clean_2.pth
# skip  1166 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0674_00_vh_clean_2.pth
# skip  1167 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0674_01_vh_clean_2.pth
# skip  1168 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0675_00_vh_clean_2.pth
# skip  1169 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0675_01_vh_clean_2.pth
# skip  1170 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0676_00_vh_clean_2.pth
# skip  1171 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0676_01_vh_clean_2.pth
# skip  1172 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0677_00_vh_clean_2.pth
# skip  1173 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0677_01_vh_clean_2.pth
# skip  1174 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0677_02_vh_clean_2.pth
# skip  1175 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0679_00_vh_clean_2.pth
# skip  1176 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0679_01_vh_clean_2.pth
# skip  1177 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0680_00_vh_clean_2.pth
# skip  1178 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0680_01_vh_clean_2.pth
# skip  1179 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0681_00_vh_clean_2.pth
# skip  1180 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0682_00_vh_clean_2.pth
# skip  1181 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0683_00_vh_clean_2.pth
# skip  1182 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0687_00_vh_clean_2.pth
# skip  1183 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0688_00_vh_clean_2.pth
# skip  1184 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0691_00_vh_clean_2.pth
# skip  1185 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0691_01_vh_clean_2.pth
# skip  1186 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0692_00_vh_clean_2.pth
# skip  1187 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0692_01_vh_clean_2.pth
# skip  1188 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0692_02_vh_clean_2.pth
# skip  1189 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0692_03_vh_clean_2.pth
# skip  1190 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0692_04_vh_clean_2.pth
# skip  1191 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0694_00_vh_clean_2.pth
# skip  1192 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0694_01_vh_clean_2.pth
# skip  1193 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0698_00_vh_clean_2.pth
# skip  1194 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0698_01_vh_clean_2.pth
# skip  1195 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0703_00_vh_clean_2.pth
# skip  1196 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0703_01_vh_clean_2.pth
# skip  1197 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0705_00_vh_clean_2.pth
# skip  1198 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0705_01_vh_clean_2.pth
# skip  1199 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0705_02_vh_clean_2.pth
# skip  1200 D:/AT3DCV_Data/Preprocessed_OpenScene/data\scannet_3d\train\scene0706_00_vh_clean_2.pth
